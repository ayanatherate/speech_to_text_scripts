# %%
# -*- coding: utf-8 -
import time
import os
import json
import requests # pip install requests
import pandas as pd # pip install pandas



class AssemblyAI:
    BASE_URL = 'https://api.assemblyai.com/v2/'
    
    def __init__(self, api_key):
        self.api_key = api_key

    @property
    def headers(self):
        return {'authorization': self.api_key}

    def upload_audio_by_url(self, url_link, remove_filler_word=True, format_text=True, **kwarg):
        request_body = {
            'audio_url': url_link,
            'disfluencies': remove_filler_word,
            'format_text': format_text
        }

        for key, val in kwarg.items():
            request_body[key] = val

        response = requests.post(self.BASE_URL + 'transcript', headers=self.headers, json=request_body)
        return response

    def upload_audio_by_file(self, audio_file_path, chunk_size=5241880, remove_filler_word=True, format_text=True, **kwarg):
        if not os.path.exists(audio_file_path) or not os.path.isfile(audio_file_path):
            print('File is not found')
            return
        
        def read_file(file_path, chunk_size=chunk_size):
            with open(file_path, mode='rb') as _file:
                while True:
                    data = _file.read(chunk_size)
                    if not data:
                        break
                    yield data
        
        audio_data = read_file(audio_file_path)
        headers = self.headers
        headers['content-type'] = 'application/json'
        upload_response = requests.post(self.BASE_URL + 'upload', headers=headers, data=audio_data)
        
        response = self.upload_audio_by_url(upload_response.json()['upload_url'], remove_filler_word=remove_filler_word, format_text=format_text, **kwarg)
        return response

    def retrieve_transcript(self, transcript_id):
        response = requests.get(self.BASE_URL + 'transcript/' + transcript_id, headers=self.headers)
        return response.json()

# %%
from rich import print
#from assembly import AssemblyAI

API_KEY = '3cffdc8f80594aaca8652088ac71bdf0'

ai1 = AssemblyAI(API_KEY)


media_file_path = r'C:\Users\User\Downloads\hh.wav'
response_upload = ai1.upload_audio_by_file(media_file_path)
response_json_output = response_upload.json()
transcript_id = response_json_output['id']



response_status = ai1.retrieve_transcript(transcript_id)

temp=response_status['status']
while temp=='processing':
    
    temp_res= ai1.retrieve_transcript(transcript_id)
    temp=temp_res['status']
    if temp=='completed':
        print(temp_res['text'])
    else:
        continue
# Out:
# Cuban at the docker, Ansible, etc. So these all are my technical skills and I've also used
# this skill to build several projects which includes user management project and attendance
# management project. I've also participated in Smart India Hatches, on which one we also got
# to the final. These are more my technical skills coming to my extracurricular activities. I
# love to dance, particularly some classical dance. I also like to read, write and paint. I
# have been the student editor of our for the Best and Fine and currently I am one of the
# cultural heads of our Students Club. So I have also participated in several donation camps.
# Several donation camps. And I am a member of the Rochi Club or Deport. I consider myself as a
# very focused person and I always work towards my goals and in a very efficient manner. I am a
# team player and very optimistic in tough time. And that way I would like to say that why not
# start the journey of my success by the success of joining GPS. Thank you so much. Okay, what
# are the five specific points which makes easier different from other ideas? This has a brand
# name. It is a multinational company and it has a very good brand name and that gives me a
# good start for my customer. Secondly, it has a work life pattern. I have talked to many of my
# friends who are in TTS and they say that TTS gives a very good work life pattern. So that is
# the second point. Third point is the colleagues there are very futuristic and their skills,
# so there is a lot to learn from them. I think this is a multinational company. I would like
# to I would have the chance to even go abroad and talk people of different nationalities. And
# lastly, as CTS has been in the industry for almost 150 years, so it gives me a sense of job
# security to some extent. Okay, what are the ethical values? Like I said, there is a website
# balance and it promotes gender equality. There is no discrimination on the basis of that. So
# it's very good in ethics overall. Okay, buddy, nice talking to you. Next part of it. Thank
# you. Yes, sir. Which, uh, other interviews have you appeared for it? What has been the
# results? I have interviewed for the Net, which is only and I got selected for it. I also
# interviewed for Gateway and that's it. I was not selected in the interview. I got to the
# interview part but was not selected, so that's only a given reason. Okay, uh, have you
# analyzed why you didn't get selected for Gateway? So in Gateway, I might have not asked the
# technical questions very well as compared to the other candidates. Okay, so how have you
# prepared for me my technical skills? I have been preparing for the course upgrade and I've
# been doing coding almost every day. So I think that I prepared quite well for this. Okay,
# sorry, tell me, what are your future plans? So my future plan? Uh, if I join PCs or
# otherwise, what are your future plans? So I want to join a software company and work for that
# and I want to learn as much languages and as much skills as I can and I also want to achieve
# great success so that I am satisfied with what I've done. Okay, what do you think are the
# reasons for youngsters switching over jobs? So maybe it was job satisfaction because they
# entered a company without seeing the background of the company and then they later find out
# that the company was not suitable for them. Okay, as for you, what are the three important
# things that, uh, one should consider before joining any organization as a pressure? So,
# firstly, the one should look if there is a lot to learn from the company, I mean, there
# should be a very cheap growing curve in the company. Secondly, there should be the colleagues
# and everything should be very frank so that they help you in every way and so for me, there
# should be a brand name so that there is a satisfaction that, yes, I've achieved a level and
# now I can go to the next level. Okay, technically, what gives you job certificate?
# Technically, I want to work with latest technical skills like not obsolete technologies, but
# the latest technology. So how does TCS fit into your requirements? TCS changes its
# technologies according to the needs of the people. There is no strict technology that they
# use. They use according to their clients which are the major clients of DC. Can you name
# three of both of them? Sorry, so but I'm not aware of the clients. Okay, anything that you
# want to ask? Will I be able to fit into the company? Yeah. As for your own analysis, you said
# you're a good team player and what requirements you set for a good, uh, job. In case you have
# those qualities, I'm sure you will be able to get it. Okay, thank you. Any more suggestions
# for me? No, nothing. Thank you so much. All the best.
